# %%
import os
from dotenv import load_dotenv
from dataClass import DataTable
from langchain_mistralai import ChatMistralAI
import json
import requests
import pandas as pd

# %%
import re

def extract_id(input_str):
    # Regular expression pattern to match the ID in both formats
    pattern = r"Q\d+"

    # Search for the pattern in the input string
    match = re.search(pattern, input_str)

    # If a match is found, return the matched ID, otherwise return None or an appropriate message
    if match:
        return match.group(0)
    else:
        return None

# %%
gt = pd.read_csv('data/HardTablesR1/DataSets/HardTablesR1/Valid/gt/cea_gt.csv', header=None)  
gt.head()
# Out:
#           0  1  2                                        3
# 0  NQK7B1JD  1  0  http://www.wikidata.org/entity/Q7996268
# 1  NQK7B1JD  2  0  http://www.wikidata.org/entity/Q7996260
# 2  NQK7B1JD  3  0  http://www.wikidata.org/entity/Q7996231
# 3  IH9YIR7T  1  0  http://www.wikidata.org/entity/Q1760847
# 4  IH9YIR7T  2  0  http://www.wikidata.org/entity/Q1501976

# %%
import numpy as np
predictions = gt.copy()
predictions['pred_desc'] = np.nan
predictions['pred_nodesc'] = np.nan
predictions.head()
# Out:
#           0  1  2                                        3  pred_desc  \
# 0  NQK7B1JD  1  0  http://www.wikidata.org/entity/Q7996268        NaN
# 1  NQK7B1JD  2  0  http://www.wikidata.org/entity/Q7996260        NaN
# 2  NQK7B1JD  3  0  http://www.wikidata.org/entity/Q7996231        NaN
# 3  IH9YIR7T  1  0  http://www.wikidata.org/entity/Q1760847        NaN
# 4  IH9YIR7T  2  0  http://www.wikidata.org/entity/Q1501976        NaN
#
#    pred_nodesc
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
with open("results/outputsCEA_LLAMA3.json") as f:
    out = json.load(f)

# %%
import numpy as np

preds_desc, preds_nodesc = [], []

for i, (t_name, r, c, true) in gt.iterrows():
    print(f"\n______________________________\n{(t_name, r, c, true)}")

    key = str((r, c))
    if key in out[t_name]:
        print(f"\nTable Name: {out[t_name][key]['cell']}")
        if 'output_desc' in out[t_name][key]:
            pred_desc = extract_id(out[t_name][key]['output_desc'])
        else:
            print(f"\nOutput desc not found for key {key}")
            pred_desc = np.nan
        if 'output_nodesc' in out[t_name][key]:
            pred_nodesc = extract_id(out[t_name][key]['output_nodesc'])
        else:
            print(f"\nOutput nodesc not found for key {key}")
            pred_nodesc = np.nan
    else:
        print(f"\nTable Name: Key {key} not found")
        pred_desc = np.nan
        pred_nodesc = np.nan

    true_id = true.split('/')[-1]

    print(f"True: {true_id}")
    print(f"Pred desc: {pred_desc}")
    print(f"Pred nodesc: {pred_nodesc}")

    print(f"\n\nDESC    : {true_id == pred_desc}")
    print(f"NO DESC : {true_id == pred_nodesc}")

    preds_desc.append(pred_desc)
    preds_nodesc.append(pred_nodesc)
# Out:
# ______________________________
# ('NQK7B1JD', 1, 0, 'http://www.wikidata.org/entity/Q7996268')
#
# Table Name: lincoln township
# True: Q7996268
# Pred desc: Q555980
# Pred nodesc: Q9041465
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('NQK7B1JD', 2, 0, 'http://www.wikidata.org/entity/Q7996260')
#
# Table Name: stony creek township
# True: Q7996260
# Pred desc: Q6031887
# Pred nodesc: Q6031889
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('NQK7B1JD', 3, 0, 'http://www.wikidata.org/entity/Q7996231')
#
# Table Name: hartford township
# True: Q7996231
# Pred desc: Q9039946
# Pred nodesc: Q14709910
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('IH9YIR7T', 1, 0, 'http://www.wikidata.org/entity/Q1760847')
#
# Table Name: national assembly
# True: Q1760847
# Pred desc: Q1512579
# Pred nodesc: Q5283279
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('IH9YIR7T', 2, 0, 'http://www.wikidata.org/entity/Q1501976')
#
# Table Name: house of representatives
# True: Q1501976
# Pred desc: Q1137584
# Pred nodesc: Q11701
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('IH9YIR7T', 3, 0, 'http://www.wikidata.org/entity/Q1319595')
#
# Table Name: national assembly
# True: Q1319595
# Pred desc: Q275854
# Pred nodesc: Q15261102
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('5NFRSNRM', 1, 0, 'http://www.wikidata.org/entity/Q6677505')
#
# Table Name: flag of alexeyevsky district
# True: Q6677505
# Pred desc: Q4486711
# Pred nodesc: Q4485341
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('5NFRSNRM', 2, 0, 'http://www.wikidata.org/entity/Q18216724')
#
# Table Name: flag of nikolayevsky district
# True: Q18216724
# Pred desc: Q4487129
# Pred nodesc: Q4487129
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('5NFRSNRM', 3, 0, 'http://www.wikidata.org/entity/Q4486711')
#
# Table Name: flag of kuybyshevsky district
# True: Q4486711
# Pred desc: Q4486710
# Pred nodesc: Q4486710
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('9SKOZCJN', 1, 0, 'http://www.wikidata.org/entity/Q109803831')
#
# Table Name: sirkeci railway station
# True: Q109803831
# Pred desc: Q800974
# Pred nodesc: Q800974
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('9SKOZCJN', 2, 0, 'http://www.wikidata.org/entity/Q106086519')
#
# Table Name: potsdamer platz s-bahn station
# True: Q106086519
# Pred desc: Q106086519
# Pred nodesc: Q106086519
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('9SKOZCJN', 3, 0, 'http://www.wikidata.org/entity/Q105635178')
#
# Table Name: münchen hbf (tief) station
# True: Q105635178
# Pred desc: Q557448
# Pred nodesc: Q157
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('9SKOZCJN', 4, 0, 'http://www.wikidata.org/entity/Q87195419')
#
# Table Name: santa maria di licodia sud railway station
# True: Q87195419
# Pred desc: Q87195419
# Pred nodesc: Q87195419
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('9SKOZCJN', 5, 0, 'http://www.wikidata.org/entity/Q70585725')
#
# Table Name: s-bahnhof hamburg-altona
# True: Q70585725
# Pred desc: Q800874
# Pred nodesc: Q800874
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('9SKOZCJN', 6, 0, 'http://www.wikidata.org/entity/Q53261512')
#
# Table Name: stuttgart feuersee station
# True: Q53261512
# Pred desc: Q53261512
# Pred nodesc: Q53261512
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('9NYXE8JY', 1, 0, 'http://www.wikidata.org/entity/Q5581472')
#
# Table Name: gondolin cdve
# True: Q5581472
# Pred desc: Q5581472
# Pred nodesc: Q5581472
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('9NYXE8JY', 2, 0, 'http://www.wikidata.org/entity/Q5563141')
#
# Table Name: ginkgo petrified forest state par
# True: Q5563141
# Pred desc: Q5563141
# Pred nodesc: Q5563141
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('9NYXE8JY', 3, 0, 'http://www.wikidata.org/entity/Q5167942')
#
# Table Name: cropers cave
# True: Q5167942
# Pred desc: Q12277279
# Pred nodesc: Q52855167
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('9NYXE8JY', 4, 0, 'http://www.wikidata.org/entity/Q3564060')
#
# Table Name: prokop vally
# True: Q3564060
# Pred desc: Q35242923
# Pred nodesc: Q35242923
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('X1FK1EL9', 1, 0, 'http://www.wikidata.org/entity/Q108396699')
#
# Table Name: parsey, sage, rosemary and thyme
# True: Q108396699
# Pred desc: Q747405
# Pred nodesc: Q747405
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('X1FK1EL9', 2, 0, 'http://www.wikidata.org/entity/Q108396514')
#
# Table Name: sounds of ilhnce
# True: Q108396514
# Pred desc: Q7564887
# Pred nodesc: Q7564928
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('X1FK1EL9', 3, 0, 'http://www.wikidata.org/entity/Q108389999')
#
# Table Name: Key (3, 0) not found
# True: Q108389999
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('X1FK1EL9', 4, 0, 'http://www.wikidata.org/entity/Q108389895')
#
# Table Name: Key (4, 0) not found
# True: Q108389895
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('X1FK1EL9', 5, 0, 'http://www.wikidata.org/entity/Q108334941')
#
# Table Name: Key (5, 0) not found
# True: Q108334941
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('9PRE1ZTN', 1, 0, 'http://www.wikidata.org/entity/Q487564')
#
# Table Name: herkimer county
# True: Q487564
# Pred desc: Q487564
# Pred nodesc: Q487564
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('9PRE1ZTN', 1, 1, 'http://www.wikidata.org/entity/Q1384')
#
# Table Name: new york
# True: Q1384
# Pred desc: Q1384
# Pred nodesc: Q1384
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('9PRE1ZTN', 2, 0, 'http://www.wikidata.org/entity/Q156566')
#
# Table Name: rensselaer county
# True: Q156566
# Pred desc: Q156566
# Pred nodesc: Q156566
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('9PRE1ZTN', 2, 1, 'http://www.wikidata.org/entity/Q1384')
#
# Table Name: new york
# True: Q1384
# Pred desc: Q1384
# Pred nodesc: None
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('9PRE1ZTN', 3, 0, 'http://www.wikidata.org/entity/Q115014')
#
# Table Name: genesee county
# True: Q115014
# Pred desc: Q115014
# Pred nodesc: Q115014
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('9PRE1ZTN', 3, 1, 'http://www.wikidata.org/entity/Q1384')
#
# Table Name: new york
# True: Q1384
# Pred desc: Q1384
# Pred nodesc: None
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('9PRE1ZTN', 4, 0, 'http://www.wikidata.org/entity/Q114992')
#
# Table Name: essex county
# True: Q114992
# Pred desc: Q114992
# Pred nodesc: Q114992
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('9PRE1ZTN', 4, 1, 'http://www.wikidata.org/entity/Q1384')
#
# Table Name: new york
# True: Q1384
# Pred desc: Q1384
# Pred nodesc: Q1384
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('9PRE1ZTN', 5, 0, 'http://www.wikidata.org/entity/Q115289')
#
# Table Name: delaware county
# True: Q115289
# Pred desc: Q115289
# Pred nodesc: Q115289
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('9PRE1ZTN', 5, 1, 'http://www.wikidata.org/entity/Q1384')
#
# Table Name: new york
# True: Q1384
# Pred desc: Q1384
# Pred nodesc: Q1384
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('9PRE1ZTN', 6, 0, 'http://www.wikidata.org/entity/Q115266')
#
# Table Name: putnam county
# True: Q115266
# Pred desc: Q115266
# Pred nodesc: None
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('9PRE1ZTN', 6, 1, 'http://www.wikidata.org/entity/Q1384')
#
# Table Name: new york
# True: Q1384
# Pred desc: Q1384
# Pred nodesc: Q60
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('C93XQVXO', 1, 0, 'http://www.wikidata.org/entity/Q854630')
#
# Table Name: chemung cownty
# True: Q854630
# Pred desc: Q854630
# Pred nodesc: Q854630
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('C93XQVXO', 2, 0, 'http://www.wikidata.org/entity/Q500569')
#
# Table Name: st. lawrence couny
# True: Q500569
# Pred desc: Q500569
# Pred nodesc: Q500569
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('C93XQVXO', 3, 0, 'http://www.wikidata.org/entity/Q487616')
#
# Table Name: chenango ounty
# True: Q487616
# Pred desc: Q487616
# Pred nodesc: Q487616
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('LCBAIKDQ', 1, 0, 'http://www.wikidata.org/entity/Q32232812')
#
# Table Name: edsforsen
# True: Q32232812
# Pred desc: Q32232812
# Pred nodesc: Q32232812
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('LCBAIKDQ', 2, 0, 'http://www.wikidata.org/entity/Q32232255')
#
# Table Name: dunderforsen
# True: Q32232255
# Pred desc: Q32232255
# Pred nodesc: Q32232255
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('LCBAIKDQ', 3, 0, 'http://www.wikidata.org/entity/Q32227585')
#
# Table Name: brattforsen
# True: Q32227585
# Pred desc: Q34834316
# Pred nodesc: Q32227577
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('LCBAIKDQ', 4, 0, 'http://www.wikidata.org/entity/Q32227577')
#
# Table Name: brattforsen
# True: Q32227577
# Pred desc: Q34834316
# Pred nodesc: Q32227577
#
#
# DESC    : False
# NO DESC : True
#
# ______________________________
# ('LCBAIKDQ', 5, 0, 'http://www.wikidata.org/entity/Q32193007')
#
# Table Name: emily falls
# True: Q32193007
# Pred desc: Q32192993
# Pred nodesc: Q32192993
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('LCBAIKDQ', 6, 0, 'http://www.wikidata.org/entity/Q34760029')
#
# Table Name: storfossen
# True: Q34760029
# Pred desc: Q34760021
# Pred nodesc: Q34759355
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('P0ZSGNRQ', 1, 0, 'http://www.wikidata.org/entity/Q3655111')
#
# Table Name: Key (1, 0) not found
# True: Q3655111
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('P0ZSGNRQ', 2, 0, 'http://www.wikidata.org/entity/Q3268124')
#
# Table Name: Key (2, 0) not found
# True: Q3268124
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('P0ZSGNRQ', 3, 0, 'http://www.wikidata.org/entity/Q2707611')
#
# Table Name: s astoria
# True: Q2707611
# Pred desc: Q2707611
# Pred nodesc: Q2707611
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('P0ZSGNRQ', 4, 0, 'http://www.wikidata.org/entity/Q2631516')
#
# Table Name: ms york (90)
# True: Q2631516
# Pred desc: Q2631516
# Pred nodesc: Q65236951
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('P0ZSGNRQ', 5, 0, 'http://www.wikidata.org/entity/Q2555195')
#
# Table Name: Key (5, 0) not found
# True: Q2555195
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('89GM9ZJW', 1, 0, 'http://www.wikidata.org/entity/Q67200083')
#
# Table Name: landesbühne (lenz)
# True: Q67200083
# Pred desc: Q67200083
# Pred nodesc: Q67200083
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('89GM9ZJW', 1, 1, 'http://www.wikidata.org/entity/Q76412')
#
# Table Name: siegfried lenz
# True: Q76412
# Pred desc: Q76412
# Pred nodesc: Q76417
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('89GM9ZJW', 1, 2, 'http://www.wikidata.org/entity/Q2152124')
#
# Table Name: hoffmann und campe
# True: Q2152124
# Pred desc: Q2152124
# Pred nodesc: Q2152124
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('89GM9ZJW', 2, 0, 'http://www.wikidata.org/entity/Q67086798')
#
# Table Name: narrative of a second expedition to the shores of the polar sea in the years 1825, 1826, and 1827
# True: Q67086798
# Pred desc: Q67086798
# Pred nodesc: Q67086798
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('89GM9ZJW', 2, 1, 'http://www.wikidata.org/entity/Q545944')
#
# Table Name: john richardson
# True: Q545944
# Pred desc: Q15506292
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('89GM9ZJW', 2, 2, 'http://www.wikidata.org/entity/Q1232629')
#
# Table Name: john murray
# True: Q1232629
# Pred desc: Q1232629
# Pred nodesc: Q1232629
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('89GM9ZJW', 3, 0, 'http://www.wikidata.org/entity/Q74039895')
#
# Table Name: the life and travels of thomas simpson, the arctic discoverer
# True: Q74039895
# Pred desc: Q74039895
# Pred nodesc: Q74039895
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('89GM9ZJW', 3, 1, 'http://www.wikidata.org/entity/Q74029515')
#
# Table Name: alexander simpson
# True: Q74029515
# Pred desc: Q74029515
# Pred nodesc: Q74029515
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('89GM9ZJW', 3, 2, 'http://www.wikidata.org/entity/Q172299')
#
# Table Name: richard bentley
# True: Q172299
# Pred desc: Q172299
# Pred nodesc: Q172299
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('KJQGZ38D', 1, 0, 'http://www.wikidata.org/entity/Q12259693')
#
# Table Name: ipui onac
# True: Q12259693
# Pred desc: Q12259693
# Pred nodesc: Q12259693
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('KJQGZ38D', 1, 1, 'http://www.wikidata.org/entity/Q19652')
#
# Table Name: Key (1, 1) not found
# True: Q19652
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('KJQGZ38D', 1, 2, 'http://www.wikidata.org/entity/Q693')
#
# Table Name: Key (1, 2) not found
# True: Q693
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('KJQGZ38D', 2, 0, 'http://www.wikidata.org/entity/Q3828522')
#
# Table Name: the adventures of ulysses
# True: Q3828522
# Pred desc: Q3828522
# Pred nodesc: Q3828522
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('KJQGZ38D', 2, 1, 'http://www.wikidata.org/entity/Q19652')
#
# Table Name: Key (2, 1) not found
# True: Q19652
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('KJQGZ38D', 2, 2, 'http://www.wikidata.org/entity/Q8261')
#
# Table Name: Key (2, 2) not found
# True: Q8261
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('KJQGZ38D', 3, 0, 'http://www.wikidata.org/entity/Q24041092')
#
# Table Name: mr. and mrs. elliot
# True: Q24041092
# Pred desc: Q24041092
# Pred nodesc: Q24041092
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('KJQGZ38D', 3, 1, 'http://www.wikidata.org/entity/Q19652')
#
# Table Name: Key (3, 1) not found
# True: Q19652
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('KJQGZ38D', 3, 2, 'http://www.wikidata.org/entity/Q49084')
#
# Table Name: Key (3, 2) not found
# True: Q49084
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('KJQGZ38D', 4, 0, 'http://www.wikidata.org/entity/Q19973853')
#
# Table Name: de binocle
# True: Q19973853
# Pred desc: Q19973853
# Pred nodesc: Q19973853
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('KJQGZ38D', 4, 1, 'http://www.wikidata.org/entity/Q19652')
#
# Table Name: Key (4, 1) not found
# True: Q19652
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('KJQGZ38D', 4, 2, 'http://www.wikidata.org/entity/Q49084')
#
# Table Name: Key (4, 2) not found
# True: Q49084
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('C1TYEJXD', 1, 0, 'http://www.wikidata.org/entity/Q1024908')
#
# Table Name: Key (1, 0) not found
# True: Q1024908
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('C1TYEJXD', 2, 0, 'http://www.wikidata.org/entity/Q10280206')
#
# Table Name: Key (2, 0) not found
# True: Q10280206
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('C1TYEJXD', 3, 0, 'http://www.wikidata.org/entity/Q10280193')
#
# Table Name: Key (3, 0) not found
# True: Q10280193
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('C1TYEJXD', 4, 0, 'http://www.wikidata.org/entity/Q10280187')
#
# Table Name: forte do avalo lighthouse
# True: Q10280187
# Pred desc: Q10280187
# Pred nodesc: Q10280187
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('C1TYEJXD', 5, 0, 'http://www.wikidata.org/entity/Q10280171')
#
# Table Name: Key (5, 0) not found
# True: Q10280171
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('C1TYEJXD', 6, 0, 'http://www.wikidata.org/entity/Q10280146')
#
# Table Name: azurara rearlighthouse
# True: Q10280146
# Pred desc: Q10280146
# Pred nodesc: Q10280146
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('W8AVXGFZ', 1, 0, 'http://www.wikidata.org/entity/Q5436130')
#
# Table Name: regufe lghthouse
# True: Q5436130
# Pred desc: Q5436130
# Pred nodesc: Q5436130
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('W8AVXGFZ', 2, 0, 'http://www.wikidata.org/entity/Q5436125')
#
# Table Name: Key (2, 0) not found
# True: Q5436125
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('W8AVXGFZ', 3, 0, 'http://www.wikidata.org/entity/Q11681789')
#
# Table Name: abo espichel lightouse
# True: Q11681789
# Pred desc: Q11681789
# Pred nodesc: Q11681789
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('LCAPKZ06', 1, 0, 'http://www.wikidata.org/entity/Q19612918')
#
# Table Name: solar star
# True: Q19612918
# Pred desc: Q19612918
# Pred nodesc: Q19612918
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('LCAPKZ06', 2, 0, 'http://www.wikidata.org/entity/Q111010045')
#
# Table Name: girasol
# True: Q111010045
# Pred desc: Q26949
# Pred nodesc: Q111010045
#
#
# DESC    : False
# NO DESC : True
#
# ______________________________
# ('LCAPKZ06', 3, 0, 'http://www.wikidata.org/entity/Q92767598')
#
# Table Name: kidston solar farm
# True: Q92767598
# Pred desc: Q92767598
# Pred nodesc: Q92767598
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('OFL33CS3', 1, 0, 'http://www.wikidata.org/entity/Q12100382')
#
# Table Name: state agency of watr resources of ukraine
# True: Q12100382
# Pred desc: Q12100382
# Pred nodesc: Q12100382
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('OFL33CS3', 2, 0, 'http://www.wikidata.org/entity/Q12100322')
#
# Table Name: Key (2, 0) not found
# True: Q12100322
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('OFL33CS3', 3, 0, 'http://www.wikidata.org/entity/Q2915414')
#
# Table Name: nationcl bureau of investigation
# True: Q2915414
# Pred desc: Q1216661
# Pred nodesc: Q2331026
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('K3ML0XEJ', 1, 0, 'http://www.wikidata.org/entity/Q6905653')
#
# Table Name: montgomery bell state prk
# True: Q6905653
# Pred desc: Q6905653
# Pred nodesc: Q6905653
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('K3ML0XEJ', 2, 0, 'http://www.wikidata.org/entity/Q5723264')
#
# Table Name: henry horton state rark
# True: Q5723264
# Pred desc: Q5723264
# Pred nodesc: Q5723264
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('K3ML0XEJ', 3, 0, 'http://www.wikidata.org/entity/Q5432019')
#
# Table Name: fall#creek falls state park
# True: Q5432019
# Pred desc: Q5432019
# Pred nodesc: None
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('K3ML0XEJ', 4, 0, 'http://www.wikidata.org/entity/Q5337229')
#
# Table Name: edgar evins suate park
# True: Q5337229
# Pred desc: Q5337229
# Pred nodesc: Q5337229
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('K3ML0XEJ', 5, 0, 'http://www.wikidata.org/entity/Q5178932')
#
# Table Name: ove lake state pak
# True: Q5178932
# Pred desc: Q5178932
# Pred nodesc: None
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('CFYKPBO3', 1, 0, 'http://www.wikidata.org/entity/Q73848923')
#
# Table Name: toba city toba elementary school
# True: Q73848923
# Pred desc: Q73848923
# Pred nodesc: Q73848923
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('CFYKPBO3', 2, 0, 'http://www.wikidata.org/entity/Q65262340')
#
# Table Name: fuji city imaizumi elementary school
# True: Q65262340
# Pred desc: Q65262340
# Pred nodesc: Q65262340
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('CFYKPBO3', 3, 0, 'http://www.wikidata.org/entity/Q60985901')
#
# Table Name: kuroishi shiritsu botandaira shōgakkō
# True: Q60985901
# Pred desc: Q60985901
# Pred nodesc: Q60985901
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('I7OIFNCX', 1, 0, 'http://www.wikidata.org/entity/Q6021009')
#
# Table Name: indian national academy of engineering
# True: Q6021009
# Pred desc: Q6021009
# Pred nodesc: Q6021009
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('I7OIFNCX', 1, 1, 'http://www.wikidata.org/entity/Q987')
#
# Table Name: new delhi
# True: Q987
# Pred desc: Q987
# Pred nodesc: Q987
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('I7OIFNCX', 2, 0, 'http://www.wikidata.org/entity/Q9066994')
#
# Table Name: royal academy of sciences and arts of barcelona
# True: Q9066994
# Pred desc: Q9066994
# Pred nodesc: Q9066994
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('I7OIFNCX', 2, 1, 'http://www.wikidata.org/entity/Q1492')
#
# Table Name: barcelona
# True: Q1492
# Pred desc: Q1492
# Pred nodesc: None
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('I7OIFNCX', 3, 0, 'http://www.wikidata.org/entity/Q6101686')
#
# Table Name: real academia de ciencias económicas y financieras
# True: Q6101686
# Pred desc: Q6101686
# Pred nodesc: Q6101686
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('I7OIFNCX', 3, 1, 'http://www.wikidata.org/entity/Q1492')
#
# Table Name: barcelona
# True: Q1492
# Pred desc: Q1492
# Pred nodesc: Q1492
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('I7OIFNCX', 4, 0, 'http://www.wikidata.org/entity/Q2895433')
#
# Table Name: royal academy of pharmacy
# True: Q2895433
# Pred desc: Q2895433
# Pred nodesc: Q2895433
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('I7OIFNCX', 4, 1, 'http://www.wikidata.org/entity/Q29903068')
#
# Table Name: royal academy of pharmacy building
# True: Q29903068
# Pred desc: Q2895433
# Pred nodesc: Q29903068
#
#
# DESC    : False
# NO DESC : True
#
# ______________________________
# ('I7OIFNCX', 5, 0, 'http://www.wikidata.org/entity/Q3233780')
#
# Table Name: national academies of sciences, engineering, and medicine
# True: Q3233780
# Pred desc: Q3233780
# Pred nodesc: Q3233780
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('I7OIFNCX', 5, 1, 'http://www.wikidata.org/entity/Q61')
#
# Table Name: washington, d.c.
# True: Q61
# Pred desc: Q61
# Pred nodesc: Q61
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('I7OIFNCX', 6, 0, 'http://www.wikidata.org/entity/Q3395778')
#
# Table Name: royal swedish academy of war sciences
# True: Q3395778
# Pred desc: Q247116
# Pred nodesc: Q3395778
#
#
# DESC    : False
# NO DESC : True
#
# ______________________________
# ('I7OIFNCX', 6, 1, 'http://www.wikidata.org/entity/Q1754')
#
# Table Name: stockholm
# True: Q1754
# Pred desc: Q1754
# Pred nodesc: Q1754
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('I7OIFNCX', 7, 0, 'http://www.wikidata.org/entity/Q3394637')
#
# Table Name: royal swedish academy of engineering sciences
# True: Q3394637
# Pred desc: Q3394637
# Pred nodesc: Q3394637
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('I7OIFNCX', 7, 1, 'http://www.wikidata.org/entity/Q1754')
#
# Table Name: stockholm
# True: Q1754
# Pred desc: Q1754
# Pred nodesc: None
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('OVUHMECF', 1, 0, 'http://www.wikidata.org/entity/Q651690')
#
# Table Name: polish academy of sciences
# True: Q651690
# Pred desc: Q651690
# Pred nodesc: Q651690
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('OVUHMECF', 1, 1, 'http://www.wikidata.org/entity/Q270')
#
# Table Name: warsaw
# True: Q270
# Pred desc: Q270
# Pred nodesc: Q270
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('OVUHMECF', 1, 2, 'http://www.wikidata.org/entity/Q19635956')
#
# Table Name: jerzy duszyński
# True: Q19635956
# Pred desc: Q19635956
# Pred nodesc: Q19635956
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('OVUHMECF', 2, 0, 'http://www.wikidata.org/entity/Q2379496')
#
# Table Name: national academy of sciences of armenia
# True: Q2379496
# Pred desc: Q2379496
# Pred nodesc: Q2379496
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('OVUHMECF', 2, 1, 'http://www.wikidata.org/entity/Q1953')
#
# Table Name: yerevan
# True: Q1953
# Pred desc: Q1953
# Pred nodesc: Q1953
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('OVUHMECF', 2, 2, 'http://www.wikidata.org/entity/Q164396')
#
# Table Name: victor ambartsumian
# True: Q164396
# Pred desc: Q164396
# Pred nodesc: Q164396
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('OVUHMECF', 3, 0, 'http://www.wikidata.org/entity/Q840015')
#
# Table Name: royal academy of moral and political sciences
# True: Q840015
# Pred desc: Q840015
# Pred nodesc: None
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('OVUHMECF', 3, 1, 'http://www.wikidata.org/entity/Q2807')
#
# Table Name: madrid
# True: Q2807
# Pred desc: Q2807
# Pred nodesc: None
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('OVUHMECF', 3, 2, 'http://www.wikidata.org/entity/Q3753442')
#
# Table Name: juan velarde fuertes
# True: Q3753442
# Pred desc: Q3753442
# Pred nodesc: Q3753442
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('OVUHMECF', 4, 0, 'http://www.wikidata.org/entity/Q414403')
#
# Table Name: academy of athens
# True: Q414403
# Pred desc: Q414403
# Pred nodesc: None
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('OVUHMECF', 4, 1, 'http://www.wikidata.org/entity/Q1224979')
#
# Table Name: athens municipality
# True: Q1224979
# Pred desc: Q113472475
# Pred nodesc: Q1524
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('OVUHMECF', 4, 2, 'http://www.wikidata.org/entity/Q16332891')
#
# Table Name: georgios sotiriou
# True: Q16332891
# Pred desc: Q16332891
# Pred nodesc: None
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('OVUHMECF', 5, 0, 'http://www.wikidata.org/entity/Q270920')
#
# Table Name: royal academy of arts
# True: Q270920
# Pred desc: Q270920
# Pred nodesc: Q270920
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('OVUHMECF', 5, 1, 'http://www.wikidata.org/entity/Q179351')
#
# Table Name: city of westminster
# True: Q179351
# Pred desc: Q179351
# Pred nodesc: Q179351
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('OVUHMECF', 5, 2, 'http://www.wikidata.org/entity/Q5112716')
#
# Table Name: christopher le brun
# True: Q5112716
# Pred desc: Q5112716
# Pred nodesc: Q5112716
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('NNW0J4RU', 1, 0, 'http://www.wikidata.org/entity/Q2593047')
#
# Table Name: faust
# True: Q2593047
# Pred desc: Q332885
# Pred nodesc: Q2593047
#
#
# DESC    : False
# NO DESC : True
#
# ______________________________
# ('NNW0J4RU', 1, 1, 'http://www.wikidata.org/entity/Q316165')
#
# Table Name: jan švankmajer
# True: Q316165
# Pred desc: Q316165
# Pred nodesc: Q316165
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('NNW0J4RU', 2, 0, 'http://www.wikidata.org/entity/Q2559102')
#
# Table Name: american pop
# True: Q2559102
# Pred desc: Q2559102
# Pred nodesc: Q2559102
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('NNW0J4RU', 2, 1, 'http://www.wikidata.org/entity/Q315441')
#
# Table Name: ralph bakshi
# True: Q315441
# Pred desc: Q315441
# Pred nodesc: Q315441
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('NNW0J4RU', 3, 0, 'http://www.wikidata.org/entity/Q2000923')
#
# Table Name: allegro non troppo
# True: Q2000923
# Pred desc: Q2000923
# Pred nodesc: None
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('NNW0J4RU', 3, 1, 'http://www.wikidata.org/entity/Q673304')
#
# Table Name: bruno bozzetto
# True: Q673304
# Pred desc: Q673304
# Pred nodesc: Q673304
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('HXA71H9Q', 1, 0, 'http://www.wikidata.org/entity/Q579928')
#
# Table Name: the spongebob sqwarepants movie
# True: Q579928
# Pred desc: Q579928
# Pred nodesc: Q579928
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('HXA71H9Q', 1, 2, 'http://www.wikidata.org/entity/Q22006653')
#
# Table Name: Key (1, 2) not found
# True: Q22006653
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('HXA71H9Q', 1, 3, 'http://www.wikidata.org/entity/Q4408')
#
# Table Name: mr. lawrence
# True: Q4408
# Pred desc: Q4408
# Pred nodesc: Q4408
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('HXA71H9Q', 2, 0, 'http://www.wikidata.org/entity/Q7732986')
#
# Table Name: tie fabulous baron munchausen
# True: Q7732986
# Pred desc: Q581148
# Pred nodesc: Q581148
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('HXA71H9Q', 2, 2, 'http://www.wikidata.org/entity/Q838368')
#
# Table Name: Key (2, 2) not found
# True: Q838368
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('HXA71H9Q', 2, 3, 'http://www.wikidata.org/entity/Q74699')
#
# Table Name: jan libíček
# True: Q74699
# Pred desc: Q74699
# Pred nodesc: None
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('HXA71H9Q', 3, 0, 'http://www.wikidata.org/entity/Q4281621')
#
# Table Name: paria, mirabela
# True: Q4281621
# Pred desc: Q4281621
# Pred nodesc: Q4281621
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('HXA71H9Q', 3, 2, 'http://www.wikidata.org/entity/Q22006653')
#
# Table Name: Key (3, 2) not found
# True: Q22006653
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('HXA71H9Q', 3, 3, 'http://www.wikidata.org/entity/Q12735453')
#
# Table Name: mihai constantinescu
# True: Q12735453
# Pred desc: Q12735450
# Pred nodesc: Q12735450
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('HXA71H9Q', 4, 0, 'http://www.wikidata.org/entity/Q3520383')
#
# Table Name: Key (4, 0) not found
# True: Q3520383
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('HXA71H9Q', 4, 2, 'http://www.wikidata.org/entity/Q22006653')
#
# Table Name: Key (4, 2) not found
# True: Q22006653
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('HXA71H9Q', 4, 3, 'http://www.wikidata.org/entity/Q35011')
#
# Table Name: frances fisher
# True: Q35011
# Pred desc: Q35011
# Pred nodesc: Q35011
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('HXA71H9Q', 5, 0, 'http://www.wikidata.org/entity/Q56850065')
#
# Table Name: space jam:a new legacy
# True: Q56850065
# Pred desc: Q56850065
# Pred nodesc: Q56850065
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('HXA71H9Q', 5, 2, 'http://www.wikidata.org/entity/Q22006653')
#
# Table Name: Key (5, 2) not found
# True: Q22006653
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('HXA71H9Q', 5, 3, 'http://www.wikidata.org/entity/Q45229')
#
# Table Name: zac efron
# True: Q45229
# Pred desc: Q45229
# Pred nodesc: Q45229
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('HXA71H9Q', 6, 0, 'http://www.wikidata.org/entity/Q26265')
#
# Table Name: Key (6, 0) not found
# True: Q26265
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('HXA71H9Q', 6, 2, 'http://www.wikidata.org/entity/Q22006653')
#
# Table Name: Key (6, 2) not found
# True: Q22006653
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('HXA71H9Q', 6, 3, 'http://www.wikidata.org/entity/Q2557451')
#
# Table Name: charlie adler
# True: Q2557451
# Pred desc: Q2557451
# Pred nodesc: Q29133019
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('1Z8NMAI3', 1, 0, 'http://www.wikidata.org/entity/Q2471434')
#
# Table Name: victory through air power
# True: Q2471434
# Pred desc: Q13405026
# Pred nodesc: Q2471434
#
#
# DESC    : False
# NO DESC : True
#
# ______________________________
# ('1Z8NMAI3', 1, 1, 'http://www.wikidata.org/entity/Q568631')
#
# Table Name: marc davis
# True: Q568631
# Pred desc: Q568631
# Pred nodesc: Q568631
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('1Z8NMAI3', 1, 2, 'http://www.wikidata.org/entity/Q362')
#
# Table Name: world war ii
# True: Q362
# Pred desc: Q362
# Pred nodesc: Q362
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('1Z8NMAI3', 2, 0, 'http://www.wikidata.org/entity/Q842306')
#
# Table Name: saludos amigos
# True: Q842306
# Pred desc: Q842306
# Pred nodesc: Q842306
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('1Z8NMAI3', 2, 1, 'http://www.wikidata.org/entity/Q205002')
#
# Table Name: joe grant
# True: Q205002
# Pred desc: Q205002
# Pred nodesc: Q205002
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('1Z8NMAI3', 2, 2, 'http://www.wikidata.org/entity/Q49389')
#
# Table Name: Key (2, 2) not found
# True: Q49389
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('1Z8NMAI3', 3, 0, 'http://www.wikidata.org/entity/Q80571261')
#
# Table Name: adjustment
# True: Q80571261
# Pred desc: Q80571261
# Pred nodesc: Q80571261
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('1Z8NMAI3', 3, 1, 'http://www.wikidata.org/entity/Q80570754')
#
# Table Name: ian mackinnon
# True: Q80570754
# Pred desc: Q80570754
# Pred nodesc: Q3183931
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('1Z8NMAI3', 3, 2, 'http://www.wikidata.org/entity/Q6048309')
#
# Table Name: Key (3, 2) not found
# True: Q6048309
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('D3S7HZEJ', 1, 0, 'http://www.wikidata.org/entity/Q63959132')
#
# Table Name: dharman
# True: Q63959132
# Pred desc: Q12982786
# Pred nodesc: Q12982786
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('D3S7HZEJ', 1, 1, 'http://www.wikidata.org/entity/Q901')
#
# Table Name: Key (1, 1) not found
# True: Q901
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('D3S7HZEJ', 2, 0, 'http://www.wikidata.org/entity/Q111987081')
#
# Table Name: fulgur ovid
# True: Q111987081
# Pred desc: Q111987081
# Pred nodesc: Q111987081
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('D3S7HZEJ', 2, 1, 'http://www.wikidata.org/entity/Q55155641')
#
# Table Name: Key (2, 1) not found
# True: Q55155641
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('D3S7HZEJ', 3, 0, 'http://www.wikidata.org/entity/Q104816252')
#
# Table Name: queen
# True: Q104816252
# Pred desc: Q46108996
# Pred nodesc: Q115411736
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('D3S7HZEJ', 3, 1, 'http://www.wikidata.org/entity/Q10729326')
#
# Table Name: Key (3, 1) not found
# True: Q10729326
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('D3S7HZEJ', 4, 0, 'http://www.wikidata.org/entity/Q2329269')
#
# Table Name: adam
# True: Q2329269
# Pred desc: Q108765719
# Pred nodesc: Q3105750
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('D3S7HZEJ', 4, 1, 'http://www.wikidata.org/entity/Q15883433')
#
# Table Name: Key (4, 1) not found
# True: Q15883433
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WTFHB5UP', 1, 0, 'http://www.wikidata.org/entity/Q2306089')
#
# Table Name: cyrax
# True: Q2306089
# Pred desc: Q2306089
# Pred nodesc: Q2306089
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('WTFHB5UP', 1, 1, 'http://www.wikidata.org/entity/Q9402')
#
# Table Name: Key (1, 1) not found
# True: Q9402
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WTFHB5UP', 2, 0, 'http://www.wikidata.org/entity/Q24090708')
#
# Table Name: triborg
# True: Q24090708
# Pred desc: Q24090708
# Pred nodesc: Q24090708
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('WTFHB5UP', 2, 1, 'http://www.wikidata.org/entity/Q9402')
#
# Table Name: Key (2, 1) not found
# True: Q9402
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WTFHB5UP', 3, 0, 'http://www.wikidata.org/entity/Q63349135')
#
# Table Name: gaige
# True: Q63349135
# Pred desc: Q63349135
# Pred nodesc: Q63349135
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('WTFHB5UP', 3, 1, 'http://www.wikidata.org/entity/Q62709319')
#
# Table Name: Key (3, 1) not found
# True: Q62709319
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WTFHB5UP', 4, 0, 'http://www.wikidata.org/entity/Q2262564')
#
# Table Name: nina cortex
# True: Q2262564
# Pred desc: Q2262564
# Pred nodesc: Q1992722
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('WTFHB5UP', 4, 1, 'http://www.wikidata.org/entity/Q48942')
#
# Table Name: Key (4, 1) not found
# True: Q48942
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WTFHB5UP', 5, 0, 'http://www.wikidata.org/entity/Q2267017')
#
# Table Name: cable
# True: Q2267017
# Pred desc: Q2267017
# Pred nodesc: Q2267017
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('WTFHB5UP', 5, 1, 'http://www.wikidata.org/entity/Q178197')
#
# Table Name: Key (5, 1) not found
# True: Q178197
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WTFHB5UP', 6, 0, 'http://www.wikidata.org/entity/Q2249741')
#
# Table Name: lumiya
# True: Q2249741
# Pred desc: Q2249741
# Pred nodesc: Q2249741
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('WTFHB5UP', 6, 1, 'http://www.wikidata.org/entity/Q9352089')
#
# Table Name: Key (6, 1) not found
# True: Q9352089
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('ESU2M07L', 1, 0, 'http://www.wikidata.org/entity/Q22675639')
#
# Table Name: marcus wright
# True: Q22675639
# Pred desc: Q22675639
# Pred nodesc: Q22675639
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('ESU2M07L', 1, 1, 'http://www.wikidata.org/entity/Q931260')
#
# Table Name: Key (1, 1) not found
# True: Q931260
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('ESU2M07L', 2, 0, 'http://www.wikidata.org/entity/Q62397857')
#
# Table Name: genos
# True: Q62397857
# Pred desc: Q62397857
# Pred nodesc: Q62397857
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('ESU2M07L', 2, 1, 'http://www.wikidata.org/entity/Q188784')
#
# Table Name: Key (2, 1) not found
# True: Q188784
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('ESU2M07L', 3, 0, 'http://www.wikidata.org/entity/Q49414389')
#
# Table Name: henry heywood
# True: Q49414389
# Pred desc: Q49414389
# Pred nodesc: Q49414389
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('ESU2M07L', 3, 1, 'http://www.wikidata.org/entity/Q188784')
#
# Table Name: Key (3, 1) not found
# True: Q188784
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('ESU2M07L', 4, 0, 'http://www.wikidata.org/entity/Q27926028')
#
# Table Name: john silver
# True: Q27926028
# Pred desc: Q29643590
# Pred nodesc: Q1428628
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('ESU2M07L', 4, 1, 'http://www.wikidata.org/entity/Q156839')
#
# Table Name: Key (4, 1) not found
# True: Q156839
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('AUH91PXB', 1, 0, 'http://www.wikidata.org/entity/Q22906342')
#
# Table Name: Key (1, 0) not found
# True: Q22906342
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('AUH91PXB', 2, 0, 'http://www.wikidata.org/entity/Q21070532')
#
# Table Name: Key (2, 0) not found
# True: Q21070532
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('AUH91PXB', 3, 0, 'http://www.wikidata.org/entity/Q17914035')
#
# Table Name: Key (3, 0) not found
# True: Q17914035
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('3LYGPKR9', 1, 0, 'http://www.wikidata.org/entity/Q21031158')
#
# Table Name: Key (1, 0) not found
# True: Q21031158
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('3LYGPKR9', 2, 0, 'http://www.wikidata.org/entity/Q18941713')
#
# Table Name: Key (2, 0) not found
# True: Q18941713
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('3LYGPKR9', 3, 0, 'http://www.wikidata.org/entity/Q16842889')
#
# Table Name: Key (3, 0) not found
# True: Q16842889
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('3LYGPKR9', 4, 0, 'http://www.wikidata.org/entity/Q15637095')
#
# Table Name: Key (4, 0) not found
# True: Q15637095
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('3LYGPKR9', 5, 0, 'http://www.wikidata.org/entity/Q85786462')
#
# Table Name: Key (5, 0) not found
# True: Q85786462
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('Z654ZXNI', 1, 0, 'http://www.wikidata.org/entity/Q490473')
#
# Table Name: Key (1, 0) not found
# True: Q490473
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('Z654ZXNI', 2, 0, 'http://www.wikidata.org/entity/Q5812783')
#
# Table Name: Key (2, 0) not found
# True: Q5812783
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('Z654ZXNI', 3, 0, 'http://www.wikidata.org/entity/Q300859')
#
# Table Name: Key (3, 0) not found
# True: Q300859
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('Z654ZXNI', 4, 0, 'http://www.wikidata.org/entity/Q106153383')
#
# Table Name: Key (4, 0) not found
# True: Q106153383
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('SX5IIFKD', 1, 0, 'http://www.wikidata.org/entity/Q94704608')
#
# Table Name: Key (1, 0) not found
# True: Q94704608
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('SX5IIFKD', 2, 0, 'http://www.wikidata.org/entity/Q94684476')
#
# Table Name: [fk2002] 29
# True: Q94684476
# Pred desc: Q79994687
# Pred nodesc: Q609
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('SX5IIFKD', 3, 0, 'http://www.wikidata.org/entity/Q97334250')
#
# Table Name: mahtesian 199
# True: Q97334250
# Pred desc: Q97334250
# Pred nodesc: None
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('RH67R1DF', 1, 0, 'http://www.wikidata.org/entity/Q112324447')
#
# Table Name: murder of emil grunzweig
# True: Q112324447
# Pred desc: Q112324447
# Pred nodesc: Q112324447
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('RH67R1DF', 2, 0, 'http://www.wikidata.org/entity/Q110729373')
#
# Table Name: murder of michael reynolds
# True: Q110729373
# Pred desc: Q6937777
# Pred nodesc: Q110729373
#
#
# DESC    : False
# NO DESC : True
#
# ______________________________
# ('RH67R1DF', 3, 0, 'http://www.wikidata.org/entity/Q110521837')
#
# Table Name: murder of gustáv baláž
# True: Q110521837
# Pred desc: Q110521837
# Pred nodesc: Q110521837
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('RH67R1DF', 4, 0, 'http://www.wikidata.org/entity/Q109529478')
#
# Table Name: murder of josé manuel plácido
# True: Q109529478
# Pred desc: Q108871550
# Pred nodesc: Q108871550
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('J7Z2ZKJ3', 1, 0, 'http://www.wikidata.org/entity/Q108936761')
#
# Table Name: assassination of gene viernes and silme domingo
# True: Q108936761
# Pred desc: Q108936761
# Pred nodesc: Q108936761
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('J7Z2ZKJ3', 2, 0, 'http://www.wikidata.org/entity/Q108828162')
#
# Table Name: murder of alexandros grigoropulos
# True: Q108828162
# Pred desc: Q108828162
# Pred nodesc: Q108828162
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('J7Z2ZKJ3', 3, 0, 'http://www.wikidata.org/entity/Q108442504')
#
# Table Name: murder of holly jones
# True: Q108442504
# Pred desc: Q108442504
# Pred nodesc: Q108442504
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('J7Z2ZKJ3', 4, 0, 'http://www.wikidata.org/entity/Q108294791')
#
# Table Name: murder of marwa el-sherbini
# True: Q108294791
# Pred desc: Q108294791
# Pred nodesc: Q108294791
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('J7Z2ZKJ3', 5, 0, 'http://www.wikidata.org/entity/Q107419831')
#
# Table Name: murder of samuel luiz
# True: Q107419831
# Pred desc: Q107419831
# Pred nodesc: Q107419831
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('J7Z2ZKJ3', 6, 0, 'http://www.wikidata.org/entity/Q106991501')
#
# Table Name: murder of jesse valencia
# True: Q106991501
# Pred desc: Q106991501
# Pred nodesc: Q106991501
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('J7Z2ZKJ3', 7, 0, 'http://www.wikidata.org/entity/Q106875886')
#
# Table Name: murder of william butler
# True: Q106875886
# Pred desc: Q106875886
# Pred nodesc: Q106875886
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('LS7PUF6Y', 1, 0, 'http://www.wikidata.org/entity/Q102971652')
#
# Table Name: small frog pendant
# True: Q102971652
# Pred desc: Q102971652
# Pred nodesc: Q102971652
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('LS7PUF6Y', 2, 0, 'http://www.wikidata.org/entity/Q102971643')
#
# Table Name: small eagle pendant
# True: Q102971643
# Pred desc: Q102971643
# Pred nodesc: Q102971643
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('LS7PUF6Y', 3, 0, 'http://www.wikidata.org/entity/Q102967878')
#
# Table Name: large eagle pendant
# True: Q102967878
# Pred desc: Q102967878
# Pred nodesc: Q102967878
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('LS7PUF6Y', 4, 0, 'http://www.wikidata.org/entity/Q102964666')
#
# Table Name: eagle pendant with detailed head
# True: Q102964666
# Pred desc: Q102964666
# Pred nodesc: Q102964666
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('WSXH1CEF', 1, 0, 'http://www.wikidata.org/entity/Q66010902')
#
# Table Name: chapiteau d'angle à décor de palmettes superposées sur trois registres - eba wb 114.3
# True: Q66010902
# Pred desc: Q66010902
# Pred nodesc: Q66010902
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('WSXH1CEF', 2, 0, 'http://www.wikidata.org/entity/Q66010898')
#
# Table Name: chapiteau engagé : les saints denis, rustique et éleuthère conduits devant le prévôt sisinnius - lap 1441
# True: Q66010898
# Pred desc: Q66010898
# Pred nodesc: Q66010898
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('WSXH1CEF', 3, 0, 'http://www.wikidata.org/entity/Q66010897')
#
# Table Name: chapiteau engagé : scène de la passion des saints denis, rustique et éleuthère - lap 23
# True: Q66010897
# Pred desc: Q66010897
# Pred nodesc: Q66010897
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('WSXH1CEF', 4, 0, 'http://www.wikidata.org/entity/Q66010895')
#
# Table Name: chapiteau : la parabole du riche et de lazare - lap 24
# True: Q66010895
# Pred desc: Q66010895
# Pred nodesc: Q66010895
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('WSXH1CEF', 5, 0, 'http://www.wikidata.org/entity/Q66010894')
#
# Table Name: chapiteau engagé, le jugement d'un saint personnage par un dignitaire - 108.28.1056.1
# True: Q66010894
# Pred desc: Q66010894
# Pred nodesc: Q66010894
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('WSXH1CEF', 6, 0, 'http://www.wikidata.org/entity/Q66010893')
#
# Table Name: chapiteau double engagé à décor de spirales et de têtes humaines - cl. 18626
# True: Q66010893
# Pred desc: Q66010893
# Pred nodesc: Q66010893
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('WSXH1CEF', 7, 0, 'http://www.wikidata.org/entity/Q66010892')
#
# Table Name: chapiteau d'angle à décor de chevrons entrecroisés - cl. 18630
# True: Q66010892
# Pred desc: Q66010892
# Pred nodesc: Q66010892
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('PC54CX0I', 1, 0, 'http://www.wikidata.org/entity/Q110257588')
#
# Table Name: capital
# True: Q110257588
# Pred desc: Q111867478
# Pred nodesc: Q5035431
# ...
# True: Q1740568
# Pred desc: Q1740568
# Pred nodesc: Q1740568
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('8A6358C7', 5, 1, 'http://www.wikidata.org/entity/Q1080207')
#
# Table Name: norian
# True: Q1080207
# Pred desc: Q1080207
# Pred nodesc: Q1080207
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('8A6358C7', 6, 0, 'http://www.wikidata.org/entity/Q1514704')
#
# Table Name: marchreisenspitze
# True: Q1514704
# Pred desc: Q1514704
# Pred nodesc: Q1514704
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('8A6358C7', 6, 1, 'http://www.wikidata.org/entity/Q1080207')
#
# Table Name: norian
# True: Q1080207
# Pred desc: None
# Pred nodesc: Q1080207
#
#
# DESC    : False
# NO DESC : True
#
# ______________________________
# ('Z2FMQZKH', 1, 0, 'http://www.wikidata.org/entity/Q3382290')
#
# Table Name: pico central de la cascada
# True: Q3382290
# Pred desc: Q3382290
# Pred nodesc: Q3382290
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('Z2FMQZKH', 1, 1, 'http://www.wikidata.org/entity/Q503349')
#
# Table Name: selandian
# True: Q503349
# Pred desc: Q503349
# Pred nodesc: None
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('Z2FMQZKH', 2, 0, 'http://www.wikidata.org/entity/Q6923162')
#
# Table Name: mount rebun
# True: Q6923162
# Pred desc: Q6923162
# Pred nodesc: Q6923162
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('Z2FMQZKH', 2, 1, 'http://www.wikidata.org/entity/Q752187')
#
# Table Name: early cretaceous
# True: Q752187
# Pred desc: Q44626
# Pred nodesc: Q752187
#
#
# DESC    : False
# NO DESC : True
#
# ______________________________
# ('Z2FMQZKH', 3, 0, 'http://www.wikidata.org/entity/Q3541079')
#
# Table Name: truc du midi
# True: Q3541079
# Pred desc: Q3541079
# Pred nodesc: Q3541079
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('Z2FMQZKH', 3, 1, 'http://www.wikidata.org/entity/Q500054')
#
# Table Name: middle jurassic
# True: Q500054
# Pred desc: Q500054
# Pred nodesc: Q500054
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('Z2FMQZKH', 4, 0, 'http://www.wikidata.org/entity/Q3321687')
#
# Table Name: mont bayard
# True: Q3321687
# Pred desc: Q31651722
# Pred nodesc: Q31651722
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('Z2FMQZKH', 4, 1, 'http://www.wikidata.org/entity/Q500054')
#
# Table Name: middle jurassic
# True: Q500054
# Pred desc: Q500054
# Pred nodesc: Q500054
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('Z2FMQZKH', 5, 0, 'http://www.wikidata.org/entity/Q3006348')
#
# Table Name: crêt de chalam
# True: Q3006348
# Pred desc: Q34866827
# Pred nodesc: Q34866827
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('Z2FMQZKH', 5, 1, 'http://www.wikidata.org/entity/Q500054')
#
# Table Name: middle jurassic
# True: Q500054
# Pred desc: Q500054
# Pred nodesc: Q500054
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('Z2FMQZKH', 6, 0, 'http://www.wikidata.org/entity/Q3006358')
#
# Table Name: crêt à la dame
# True: Q3006358
# Pred desc: Q3006358
# Pred nodesc: Q34867156
#
#
# DESC    : True
# NO DESC : False
#
# ______________________________
# ('Z2FMQZKH', 6, 1, 'http://www.wikidata.org/entity/Q499312')
#
# Table Name: late jurassic
# True: Q499312
# Pred desc: Q499312
# Pred nodesc: Q499312
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('Z2FMQZKH', 7, 0, 'http://www.wikidata.org/entity/Q3006352')
#
# Table Name: crêt de l'auger
# True: Q3006352
# Pred desc: Q34867156
# Pred nodesc: Q3006358
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('Z2FMQZKH', 7, 1, 'http://www.wikidata.org/entity/Q499312')
#
# Table Name: late jurassic
# True: Q499312
# Pred desc: Q499312
# Pred nodesc: Q499312
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('RK8I119S', 1, 0, 'http://www.wikidata.org/entity/Q1456446')
#
# Table Name: le reculet
# True: Q1456446
# Pred desc: Q1456446
# Pred nodesc: Q1456446
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('RK8I119S', 1, 1, 'http://www.wikidata.org/entity/Q733565')
#
# Table Name: kimmeridgian
# True: Q733565
# Pred desc: Q733565
# Pred nodesc: Q733565
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('RK8I119S', 2, 0, 'http://www.wikidata.org/entity/Q1427815')
#
# Table Name: le soliat
# True: Q1427815
# Pred desc: Q1427815
# Pred nodesc: Q1427815
#
#
# DESC    : True
# NO DESC : True
#
# ______________________________
# ('RK8I119S', 2, 1, 'http://www.wikidata.org/entity/Q733565')
#
# Table Name: kimmeridgian
# True: Q733565
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('RK8I119S', 3, 0, 'http://www.wikidata.org/entity/Q1288247')
#
# Table Name: grand crêt
# True: Q1288247
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('RK8I119S', 3, 1, 'http://www.wikidata.org/entity/Q733565')
#
# Table Name: kimmeridgian
# True: Q733565
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('RK8I119S', 4, 0, 'http://www.wikidata.org/entity/Q1110479')
#
# Table Name: colomby de gex
# True: Q1110479
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('RK8I119S', 4, 1, 'http://www.wikidata.org/entity/Q733565')
#
# Table Name: kimmeridgian
# True: Q733565
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('RK8I119S', 5, 0, 'http://www.wikidata.org/entity/Q674126')
#
# Table Name: le chasseron
# True: Q674126
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('RK8I119S', 5, 1, 'http://www.wikidata.org/entity/Q733565')
#
# Table Name: kimmeridgian
# True: Q733565
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('RK8I119S', 6, 0, 'http://www.wikidata.org/entity/Q2562097')
#
# Table Name: stormberg mountains
# True: Q2562097
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('RK8I119S', 6, 1, 'http://www.wikidata.org/entity/Q645135')
#
# Table Name: neoarchean
# True: Q645135
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('JQ14FOT4', 1, 0, 'http://www.wikidata.org/entity/Q17386829')
#
# Table Name: boumort
# True: Q17386829
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('JQ14FOT4', 2, 0, 'http://www.wikidata.org/entity/Q16608834')
#
# Table Name: el castellar
# True: Q16608834
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('JQ14FOT4', 3, 0, 'http://www.wikidata.org/entity/Q16303663')
#
# Table Name: eldhraun
# True: Q16303663
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('JQ14FOT4', 4, 0, 'http://www.wikidata.org/entity/Q15457470')
#
# Table Name: hricovec
# True: Q15457470
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('JQ14FOT4', 5, 0, 'http://www.wikidata.org/entity/Q14704319')
#
# Table Name: hughes mountain
# True: Q14704319
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('JQ14FOT4', 6, 0, 'http://www.wikidata.org/entity/Q13419805')
#
# Table Name: jankov vŕšok
# True: Q13419805
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('JQ14FOT4', 7, 0, 'http://www.wikidata.org/entity/Q12772728')
#
# Table Name: vápeč
# True: Q12772728
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('P4214UEJ', 1, 0, 'http://www.wikidata.org/entity/Q6923733')
#
# Table Name: mount sniktau
# True: Q6923733
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('P4214UEJ', 1, 1, 'http://www.wikidata.org/entity/Q111669236')
#
# Table Name: edwin howard norton patterson
# True: Q111669236
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('P4214UEJ', 2, 0, 'http://www.wikidata.org/entity/Q49052714')
#
# Table Name: mount flemer
# True: Q49052714
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('P4214UEJ', 2, 1, 'http://www.wikidata.org/entity/Q111612497')
#
# Table Name: john adolph flemer
# True: Q111612497
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('P4214UEJ', 3, 0, 'http://www.wikidata.org/entity/Q2700816')
#
# Table Name: gislifluh
# True: Q2700816
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('P4214UEJ', 3, 1, 'http://www.wikidata.org/entity/Q111356886')
#
# Table Name: gisela
# True: Q111356886
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('P4214UEJ', 4, 0, 'http://www.wikidata.org/entity/Q358573')
#
# Table Name: adlisberg
# True: Q358573
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('P4214UEJ', 4, 1, 'http://www.wikidata.org/entity/Q110769953')
#
# Table Name: adalo
# True: Q110769953
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('P4214UEJ', 5, 0, 'http://www.wikidata.org/entity/Q4862012')
#
# Table Name: barnum peak
# True: Q4862012
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('P4214UEJ', 5, 1, 'http://www.wikidata.org/entity/Q110542794')
#
# Table Name: j. d. barnum
# True: Q110542794
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('P4214UEJ', 6, 0, 'http://www.wikidata.org/entity/Q85786531')
#
# Table Name: Key (6, 0) not found
# True: Q85786531
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('P4214UEJ', 6, 1, 'http://www.wikidata.org/entity/Q110158322')
#
# Table Name: delorme donaldson cairnes
# True: Q110158322
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('1XS3T3P4', 1, 0, 'http://www.wikidata.org/entity/Q1141849')
#
# Table Name: Key (1, 0) not found
# True: Q1141849
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('1XS3T3P4', 1, 1, 'http://www.wikidata.org/entity/Q189')
#
# Table Name: iceland
# True: Q189
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('1XS3T3P4', 1, 2, 'http://www.wikidata.org/entity/Q9050633')
#
# Table Name: nordic volcanological center
# True: Q9050633
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('1XS3T3P4', 2, 0, 'http://www.wikidata.org/entity/Q207421')
#
# Table Name: tungurahua voncano
# True: Q207421
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('1XS3T3P4', 2, 1, 'http://www.wikidata.org/entity/Q736')
#
# Table Name: ecuador
# True: Q736
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('1XS3T3P4', 2, 2, 'http://www.wikidata.org/entity/Q29021307')
#
# Table Name: instituto geofísico de la escuela politécnica nacional
# True: Q29021307
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('1XS3T3P4', 3, 0, 'http://www.wikidata.org/entity/Q2670289')
#
# Table Name: Key (3, 0) not found
# True: Q2670289
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('1XS3T3P4', 3, 1, 'http://www.wikidata.org/entity/Q159')
#
# Table Name: russia
# True: Q159
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('1XS3T3P4', 3, 2, 'http://www.wikidata.org/entity/Q2656051')
#
# Table Name: institute of volcanology and seismology
# True: Q2656051
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('1XS3T3P4', 4, 0, 'http://www.wikidata.org/entity/Q2666935')
#
# Table Name: Key (4, 0) not found
# True: Q2666935
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('1XS3T3P4', 4, 1, 'http://www.wikidata.org/entity/Q159')
#
# Table Name: russia
# True: Q159
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('1XS3T3P4', 4, 2, 'http://www.wikidata.org/entity/Q2656051')
#
# Table Name: institute of volcanology and seismology
# True: Q2656051
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('1XS3T3P4', 5, 0, 'http://www.wikidata.org/entity/Q2666931')
#
# Table Name: Key (5, 0) not found
# True: Q2666931
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('1XS3T3P4', 5, 1, 'http://www.wikidata.org/entity/Q159')
#
# Table Name: russia
# True: Q159
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('1XS3T3P4', 5, 2, 'http://www.wikidata.org/entity/Q2656051')
#
# Table Name: institute of volcanology and seismology
# True: Q2656051
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WFVVMXQM', 1, 0, 'http://www.wikidata.org/entity/Q3047008')
#
# Table Name: sinjajevina
# True: Q3047008
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WFVVMXQM', 1, 2, 'http://www.wikidata.org/entity/Q82480')
#
# Table Name: Key (1, 2) not found
# True: Q82480
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WFVVMXQM', 2, 0, 'http://www.wikidata.org/entity/Q2899922')
#
# Table Name: bessillon
# True: Q2899922
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WFVVMXQM', 2, 2, 'http://www.wikidata.org/entity/Q82480')
#
# Table Name: Key (2, 2) not found
# True: Q82480
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WFVVMXQM', 3, 0, 'http://www.wikidata.org/entity/Q2894533')
#
# Table Name: beljanica
# True: Q2894533
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WFVVMXQM', 3, 2, 'http://www.wikidata.org/entity/Q23757')
#
# Table Name: Key (3, 2) not found
# True: Q23757
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WFVVMXQM', 4, 0, 'http://www.wikidata.org/entity/Q3321969')
#
# Table Name: mont myon
# True: Q3321969
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WFVVMXQM', 4, 2, 'http://www.wikidata.org/entity/Q82480')
#
# Table Name: Key (4, 2) not found
# True: Q82480
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WFVVMXQM', 5, 0, 'http://www.wikidata.org/entity/Q3297654')
#
# Table Name: massif de l'étoile
# True: Q3297654
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WFVVMXQM', 5, 2, 'http://www.wikidata.org/entity/Q23757')
#
# Table Name: Key (5, 2) not found
# True: Q23757
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WFVVMXQM', 6, 0, 'http://www.wikidata.org/entity/Q641588')
#
# Table Name: arenal volcano
# True: Q641588
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WFVVMXQM', 6, 2, 'http://www.wikidata.org/entity/Q181908')
#
# Table Name: Key (6, 2) not found
# True: Q181908
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WFVVMXQM', 7, 0, 'http://www.wikidata.org/entity/Q303806')
#
# Table Name: aavasaksa
# True: Q303806
# Pred desc: None
# Pred nodesc: None
#
#
# DESC    : False
# NO DESC : False
#
# ______________________________
# ('WFVVMXQM', 7, 2, 'http://www.wikidata.org/entity/Q513110')
#
# Table Name: Key (7, 2) not found
# True: Q513110
# Pred desc: nan
# Pred nodesc: nan
#
#
# DESC    : False
# NO DESC : False

# %%
predictions = gt.copy()
predictions['pred_desc'] = preds_desc
predictions['pred_nodesc'] = preds_nodesc
predictions = predictions.dropna()

# %%
predictions.head()
true_d, true_n = 0, 0 
diverso = 0
for i, (t_name, r, c, true, p_d, p_n) in predictions.iterrows():

    if p_d in true:
        true_d += 1
    if p_n in true:
        true_n += 1

# %%
diverso
# Out:
# 0

# %%
print(f"\n# Prompt with descriptions    | Correct: {true_d} | Accuracy: {true_d/len(predictions)*100:.2f}%")
print(f"\n# Prompt without descriptions | Correct: {true_n} | Accuracy: {true_n/len(predictions)*100:.2f}%")
# Out:
# # Prompt with descriptions    | Correct: 723 | Accuracy: 74.92%
#
# # Prompt without descriptions | Correct: 698 | Accuracy: 72.33%

# %%
predictions.head()
# Out:
#           0  1  2                                        3 pred_desc  \
# 0  NQK7B1JD  1  0  http://www.wikidata.org/entity/Q7996268   Q555980
# 1  NQK7B1JD  2  0  http://www.wikidata.org/entity/Q7996260  Q6031887
# 2  NQK7B1JD  3  0  http://www.wikidata.org/entity/Q7996231  Q9039946
# 3  IH9YIR7T  1  0  http://www.wikidata.org/entity/Q1760847  Q1512579
# 4  IH9YIR7T  2  0  http://www.wikidata.org/entity/Q1501976  Q1137584
#
#   pred_nodesc
# 0    Q9041465
# 1    Q6031889
# 2   Q14709910
# 3    Q5283279
# 4      Q11701
